# %% [markdown]
# <a href="https://colab.research.google.com/github/MrudhuhasM/Samsung-s10-Sentiment-Analysis/blob/master/Samsung_S10_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy 
import pandas as pd
import spacy

import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

from nltk.sentiment.vader import SentimentIntensityAnalyzer

import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Samsung S10', count=200)

data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

data.head()

data.iloc[5,:]
# Out:
# Tweets    RT @geekyranjit: it's been almost a month sinc...
# Name: 5, dtype: object

# %%
sid = SentimentIntensityAnalyzer()


list_scores = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  list_scores.append(ss)
  
data['polarity'] = pd.Series(list_scores).values

data.head(50)
# Out:
#                                                Tweets  \
# 0   1.) iPhone X 256gb เครื่องศูนย์ ซื้อวันนี้ ยัง...
# 1   RT @littlezaap: #พ่อยุ่งลุงไม่ว่างรีรันep8 Adเ...
# 2   RT @geekyranjit: it's been almost a month sinc...
# 3   RT @lovepope_oppa: Ad. เบรค 4 #พ่อยุ่งลุงไม่ว่...
# 4   RT @KarineApautes: Une déception pour un usage...
# 5   RT @geekyranjit: it's been almost a month sinc...
# 6   RT @littlezaap: #พ่อยุ่งลุงไม่ว่างรีรันep8 Adเ...
# 7   So may pa-libreng Samsung S10+ or whatever ba ...
# 8   RT @lovepope_oppa: Ad. เบรค 4 #พ่อยุ่งลุงไม่ว่...
# 9   RT @littlezaap: #พ่อยุ่งลุงไม่ว่างรีรันep8 Adเ...
# 10  @aanisanatasya Samsung S10 taaass. Disana udh ...
# 11  Impactante: Conozca las características del nu...
# 12  जानें, Galaxy S10+ और Google Pixel xl के मुकाब...
# 13  Samsung Galaxy S10+ 128 GB a 899,99€ https://t...
# 14  RT @lovepope_oppa: Ad. เบรค 4 #พ่อยุ่งลุงไม่ว่...
# 15  RT @littlezaap: #พ่อยุ่งลุงไม่ว่างรีรันep8 Adเ...
# ...
